# %%
import tensorflow as tf
import os
import torch 
from PIL import Image
from torch import nn, save, load
from torch.optim import Adam
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import ToTensor
import cv2
import imghdr
import numpy as np
from matplotlib import pyplot as plt
import cv2

# %%
os.path.join('models', 'horses-or-humans.h5')
# Out:
# 'models\\horses-or-humans.h5'

# %%
img = cv2.imread(os.path.join('data3','horses','horse11-1.png' ))
#img = cv2.imread(os.path.join('data3','humans','human10-04.png' ))
#img = cv2.imread('human01-00.png')
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
#plt.imshow(img)
#plt.show()

# %%
from tensorflow.keras.models import load_model

# %%
new_model = load_model(os.path.join('models', 'HoH8epochs.h4'))

# %%
resize = tf.image.resize(img, (256,256))

# %%
yhat = new_model.predict(np.expand_dims(resize/255, 0))
# Out:
# 1/1 [==============================] - 0s 90ms/step

# %%
yhat
# Out:
# array([[7.8147247e-07]], dtype=float32)

# %%
if yhat > 0.5: 
    print(f'Predicted class is a human')
else:
    print(f'Predicted class is a horse')
# Out:
# Predicted class is a horse
